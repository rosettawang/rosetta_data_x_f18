# %% [markdown]
# # Course-To-Career: Coding Implementation
#
# The following modules and examples show how a user's inputs, which consist the user's skills & and classes taken, results in a list of a website's job/internship listings ordered by best match.  Our process is broken up into these steps:
#
# 1. Scrape a list of university courses from a given university (UC Berkeley, etc.) <br>
# 2. Acquire list of job/internship listings from a given job search website (Freelancer, Indeed, etc.)<br>
# 3. Input technical skills and university courses taken by the user.<br>
# 4. Match word descriptions of listing to word description of skills/course. Points are alloted for every match & diversity of matches.<br>
# 5. Generate list of job/internship listings by highest to lowest total of points.<br>
# 6. Update by adding to input of technical skills/courses taken by the user.<br>
#
# __Note:__ For this example, let's introduce Joe, who is a fourth-year undergrad Computer Science student at UC Berkeley who possesses several technical skills and who's taken many CS classes.

# %%
# Load required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests 
import bs4 as bs
import re
from collections import Counter
import pandas as pd

# %% [markdown]
# # Scraping Courses
#
# Here, we are scraping courses from a specified university course site-- more specifically, their course names and course description.  In this example, we are scraping courses and their descriptions from the EECS Course website.

# %%
#Putting courses in a dictionary
def get_courses_in_field(field_site):    
    source = requests.get(site) 
    soup = bs.BeautifulSoup(source.content ,features='lxml') 
    prelinks = soup.find_all('a')
    
    courses_in_field = {}
    disclude = [] # A list of words that if in the prelink text, we can infer is not a course link 

    for prelink in prelinks: 
        if 'CS' in prelink.text and 'Courses' in prelink.get('href'):
            if 0 == len([k for k in disclude if k in prelink.text]):
                link = 'https://www2.eecs.berkeley.edu' + prelink.get('href')
                courses_in_field[prelink.text] = link
    return courses_in_field

def get_description(site):
    source = requests.get(site) 
    soup = bs.BeautifulSoup(source.content ,features='lxml') 
    pre = soup.find_all('p')
    for p in pre:
        if 'Catalog Description' in p.text:
            description = p.text
    listed_items = soup.find_all('li')
    for item in listed_items:
        if not item.get('class'):
            description += str(item)
    return description

# %%
#Data initialization
course_and_description = {}

# %%
site = 'https://www2.eecs.berkeley.edu/Courses/CS/'
# site = 'https://www2.eecs.berkeley.edu/Courses/EE/'
courses_in_field = get_courses_in_field(site)
#first_five = {k: courses_in_field[k] for k in list(courses_in_field)[:]}
for course in courses_in_field:
    course_link = courses_in_field[course]
    description = get_description(course_link)
    course_and_description[course] = description

# %%
len(courses_in_field)
# Out:
# 213

# %%
len(course_and_description)
# Out:
# 213

# %%
print(course_and_description)
# Out:
# {'CS C8. Foundations of Data Science': 'Catalog Description: Foundations of data science from three perspectives: inferential thinking, computational thinking, and real-world relevance. Given data arising from some real-world phenomenon, how does one analyze that data so as to understand that phenomenon? The course teaches critical concepts and skills in computer programming and statistical inference, in conjunction with hands-on analysis of real-world datasets, including economic data, document collections, geographical data, and social networks. It delves into social and legal issues surrounding data analysis, including issues of privacy and data ownership.<li><a href="https://eecs.berkeley.edu/academics">Academics</a></li><li><a href="https://eecs.berkeley.edu/academics/courses">Courses</a></li><li>\n<a href="https://eecs.berkeley.edu/privacy-policy"><span>Privacy Policy</span></a>\n</li>', 'CS C8R. Introduction to Computational Thinking with Data': 'Catalog Description: An introduction to computational thinking and quantitative reasoning, preparing students for further coursework, especially Foundations of Data Science (CS/Info/Stat C8).  Emphasizes the use of computation to gain insight about quantitative problems with real data. Expressions, data types, collections, and tables in Python. Programming practices, abstraction, and iteration.  Visualizing univariate and bivariate data with bar charts, histograms, plots, and maps. Introduction to statistical concepts including averages and distributions, predicting one variable from another, association and causality, probability and probabilistic simulation. Relationship between numerical functions and graphs. Sampling and introduction to inference.<li><a href="https://eecs.berkeley.edu/academics">Academics</a></li><li><a href="https://eecs.berkeley.edu/academics/courses">Courses</a></li><li>\n<a href="https://eecs.berkeley.edu/privacy-policy"><span>Privacy Policy</span></a>\n</li>', 'CS 9A. Matlab for Programmers': 'Catalog Description: Introduction to the constructs in the Matlab programming language, aimed at students who already know how to program. Array and matrix operations, functions and function handles, control flow, plotting and image manipulation, cell arrays and structures, and the Symbolic Mathematics toolbox. <li><a href="https://eecs.berkeley.edu/academics">Academics</a></li><li><a href="https://eecs.berkeley.edu/academics/courses">Courses</a></li><li>Arrays\n</li><li>Matrices\n</li><li>Parallel-style programming\n</li><li>Functions\n</li><li>Graphing\n</li><li>Symbolic Manipulation\n</li><li>File I/O\n</li><li>Built-in Matlab functions\n</li><li>\n<a href="https://eecs.berkeley.edu/privacy-policy"><span>Privacy Policy</span></a>\n</li>', 'CS 9A-001. Self-paced courses': 'Catalog Description: Introduction to the constructs in the Matlab programming language, aimed at students who already know how to program. Array and matrix operations, functions and function handles, control flow, plotting and image manipulation, cell arrays and structures, and the Symbolic Mathematics toolbox. <li><a href="https://eecs.berkeley.edu/academics">Academics</a></li><li><a href="https://eecs.berkeley.edu/academics/courses">Courses</a></li><li>\n<a href="https://eecs.berkeley.edu/privacy-policy"><span>Privacy Policy</span></a>\n</li>', 'CS 9C. C for Programmers': 'Catalog Description: Self-paced course in the C programming language for students who already know how to program. Computation, input and output, flow of control, functions, arrays, and pointers, linked structures, use of dynamic storage, and implementation of abstract data types. <li><a href="https://eecs.berkeley.edu/academics">Academics</a></li><li><a href="https://eecs.berkeley.edu/academics/courses">Courses</a></li><li>Computation\n</li><li>Input/Output\n</li><li>Functions and procedures\n</li><li>Flow of control\n</li><li>Arrays\n</li><li>Pointers\n</li><li>Structures\n</li><li>Files\n</li><li>Linked structures\n</l ...

# %% [markdown]
# # Scraping Jobs
#
# Here, we are scraping, from job listings from the specified jobsite (Freelancer), URLs of the website (__get_jobsites__), skills listed under each job listing (__get_jobskills__), and title of job listing (__get_title__).
#
# __Note:__ This code works only for Freelancer.  Other sites may not work with the following code.

# %%
def get_jobsites(generalsite):   
    source = requests.get(generalsite) 
    soup = bs.BeautifulSoup(source.content ,features='lxml') 
    prelinks = soup.find_all('a')

    jobsites = []
    disclude = [] # a list of words that if in the prelink text, we can infer is not a course link 

    for p in prelinks:
        if p.get('class'):
            if 'JobSearchCard-ctas-btn' == p.get('class')[0]:
                link = 'https://www.freelancer.com' + p.get('href')
                jobsites += [link]
    return jobsites
    
def get_jobskills(jobsite):
    source = requests.get(jobsite) 
    soup = bs.BeautifulSoup(source.content ,features='lxml') 
    prelinks = soup.find_all('a')
    jobskills = []
    for prelink in prelinks:
        if prelink.get('class'):
            if 'skill-navigation-link' in prelink.get('class'):
                jobskills.append(prelink.text[33:][:-29])
    return jobskills

def get_title(joblink):
    source = requests.get(joblink) 
    soup = bs.BeautifulSoup(source.content ,features='lxml') 
    title = soup.find('title')
    i = 0
    while i < len(title.text) and title.text[i] != '|':
        i += 1
    return title.text[0:i-1]

def get_sites_name_skills(jobsites, slice_number=None):
    sliced_jobsites = jobsites[:slice_number]
    jobnames = []
    jobskills = []
    for jobsite in sliced_jobsites:
        jobnames.append(get_title(jobsite))
        jobskills.append(get_jobskills(jobsite))
    return sliced_jobsites, jobnames, jobskills

# %% [markdown]
# We will initialize the data scraped from job sites. (We will make an empty list of jobs.)

# %%
# Initialize data
jobsites = []
jobnames = []
jobskills = []

# %% [markdown]
# Rerun the portion below with other links as __generalsite__ to add to the total job data.

# %%
# Choose a job site you would like to scrape.
#generalsite = 'https://www.freelancer.com/jobs/python/'
generalsite = 'https://www.freelancer.com/jobs/programming/'
# generalsite = 'https://www.freelancer.com/jobs/engineering/'

# Adding the new job data from the website specified above.
all_jobsites = get_jobsites(generalsite)
temp_sites, temp_names, temp_skills = get_sites_name_skills(all_jobsites)
jobsites += temp_sites
jobnames += temp_names
jobskills += temp_skills

# %%
# The total number of jobs has been scraped for the dataframe.
len(jobsites)
# Out:
# 100

# %% [markdown]
# Run the following code to generate a dataframe containing the job, job name, list of skills, and website for each listing scraped.

# %%
jobsdf = pd.DataFrame(index=jobnames) 
jobsdf.index.name = "Jobs"
jobsdf["List of Skills"] = jobskills
jobsdf["Website"] = jobsites
jobsdf
# Out:
#                                                                                        List of Skills  \
# Jobs
# Google Price Scraper                                                                               []
# Expert in Data mining of Image data                                                                []
# We need an experienced python/django web develo...            [Django, HTML, Javascript, PHP, Python]
# Script for Microsoft Word                                                                          []
# Django Social Media/Tinder like app fixes                     [Django, HTML, Javascript, PHP, Python]
# odoo configuration                                                          [PHP, PostgreSQL, Python]
# jenkins or gitlab CI/CD expert to help deploy m...                                                 []
# I would like to hire a Python Developer                                                            []
# Need to build a query parser for search engine                                                     []
# I need a python developer for small work            [Javascript, PHP, Python, Software Architectur...
# Finding Python Developer                                                                           []
# Data Science Trainer -- Online                      [Data Science, Machine Learning, Python, Train...
# I need a python developer                              [C Programming, Python, Software Architecture]
# Make software to scrape homeowners                                                                 []
# ESRI Python Scripts                                 [Cartography & Maps, Geospatial, Python, Softw...
# Write a script to index web for Quotations by f...                                                 []
# Medical Record system with any programming lang...      [Cryptography, Java, Javascript, PHP, Python]
# create a host in ubuntu to listen 5000 port                [Linux, PHP, Python, System Admin, Ubuntu]
# Simple python tkinter interface                                                                    []
# PHP Web application for embeded ARM system          [Embedded Software, PHP, Python, Software Arch...
# Build Simple Firewall                               [Java, Python, Software Architecture, Web Host...
# Author a technical ebook on data preparation fo...                                                 []
# Custom login form in DJango with JQuery                                                            []
# Python based ML Project Cleanup                     [Artificial Intelligence, Aws Lambda, Machine ...
# create a extension for 2d image canvas image draw   [Google Chrome, Java, Javascript, jQuery / Pro...
# Build a Employee Management System using Flask                                                     []
# Data Scientist expert needed                                                   [Data Science, Python]
# I need a python programmer                                                                         []
# ODOO 8 "OpenERP" tailoring                           [ERP, MySQL, PHP, Python, Software Architecture]
# I need to transport python code to c++                                                             []
# ...                                                                                               ...
# Hire Freelancers & Find Freelance Jobs Online -...                                                 []
# I would like to hire a Software Developer                                                          []
# MAKE A BOT ON TELEGRAM                                                                             []
# Tradingview alert script Blue Sky Day                   [C Programming, Finance, Programming, Python]
# UI Design + CFG Project                                                                            []
# Xbox Gamertag Claimer                               [C Programming, C++ Programming, Java, Program...
# clustering data streams on GPU using Matlab                                                        []
# Youtube converter software                          [C Programming, C# Programming, C++ Programmin...
# Interactive Tool for joining a series of lines ...                                                 []
# Scheme programming language expert                  [Algorithm, Engineering, Programming, Scheme, ...
# Help me make this fun and helpful desktop assis...  [C# Programming, Javascript, PHP, Programming,...
# I wanna to programmer or developer to enhanceme...  [Matlab and Mathematica, Programming, Software...
# i need an expert with R5RS software                                                                []
# Experienced Scala Developer                                                [Java, Programming, Scala]
# Data Flow Analysis (CFG) Project                                                                   []
# Build a Program Poker Program for Card recognit...                                                 []
# Applications of Assembly Language                                                                  []
# Technology(App, Website, etc) for Textile Industry                                                 []
# java program                                                                                       []
# Freshdesk + Float API intregation work/Quality ...         [Javascript, Programming, Web Development]
# Photo editing online app (exporting both raster...  [HTML5, Javascript, jQuery / Prototype, PHP, P...
# design your own t-shirt platform                    [C Programming, Graphic Design, Programming, W...
# Build me an application in Prolog                                                                  []
# Build me an application                               [Coding, Computer Science, Programming, Prolog]
# Build me a chatbot                                  [Coding, Machine Learning, Programming, Softwa...
# Write something in Bios of a GPU                                                        [Programming]
# API Expert Required                                 [API, CRM, PHP, Programming, Software Developm...
# Create area and contour in Python with Bezier c...        [Graphics Programming, Programming, Python]
# I have shopify store I need all prices images o...                                                 []
# Neurosky Mindwave EEG device visualizing EEG ou...                                                 []
#
#                                                                                               Website
# Jobs
# Google Price Scraper                                https://www.freelancer.com/projects/php/google...
# Expert in Data mining of Image data                 https://www.freelancer.com/projects/python/exp...
# We need an experienced python/django web develo...  https://www.freelancer.com/projects/php/need-e...
# Script for Microsoft Word                           https://www.freelancer.com/projects/python/scr...
# Django Social Media/Tinder like app fixes           https://www.freelancer.com/projects/php/django...
# odoo configuration                                  https://www.freelancer.com/projects/php/odoo-c...
# jenkins or gitlab CI/CD expert to help deploy m...  https://www.freelancer.com/projects/software-a...
# I would like to hire a Python Developer             https://www.freelancer.com/projects/python/wou...
# Need to build a query parser for search engine      https://www.freelancer.com/projects/python/nee...
# I need a python developer for small work            https://www.freelancer.com/projects/php/need-p...
# Finding Python Developer                            https://www.freelancer.com/projects/software-a...
# Data Science Trainer -- Online                      https://www.freelancer.com/projects/python/dat...
# I need a python developer                           https://www.freelancer.com/projects/software-a...
# Make software to scrape homeowners                  https://www.freelancer.com/projects/php/make-s...
# ESRI Python Scripts                                 https://www.freelancer.com/projects/software-a...
# Write a script to index web for Quotations by f...  https://www.freelancer.com/projects/php/write-...
# Medical Record system with any programming lang...  https://www.freelancer.com/projects/php/medica...
# create a host in ubuntu to listen 5000 port         https://www.freelancer.com/projects/php/create...
# Simple python tkinter interface                     https://www.freelancer.com/projects/python/sim...
# PHP Web application for embeded ARM system          https://www.freelancer.com/projects/php/php-we...
# Build Simple Firewall                               https://www.freelancer.com/projects/software-a...
# Author a technical ebook on data preparation fo...  https://www.freelancer.com/projects/python/aut...
# Custom login form in DJango with JQuery             https://www.freelancer.com/projects/javascript...
# Python based ML Project Cleanup                     https://www.freelancer.com/projects/python/pyt...
# create a extension for 2d image canvas image draw   https://www.freelancer.com/projects/javascript...
# Build a Employee Management System using Flask      https://www.freelancer.com/projects/css/build-...
# Data Scientist expert needed                        https://www.freelancer.com/projects/python/dat...
# I need a python programmer                          https://www.freelancer.com/projects/php/need-p...
# ODOO 8 "OpenERP" tailoring                          https://www.freelancer.com/projects/php/odoo-o...
# I need to transport python code to c++              https://www.freelancer.com/projects/software-a...
# ...                                                                                               ...
# Hire Freelancers & Find Freelance Jobs Online -...                         https://www.freelancer.com
# I would like to hire a Software Developer           https://www.freelancer.com/projects/mobile-pho...
# MAKE A BOT ON TELEGRAM                              https://www.freelancer.com/projects/php/make-b...
# Tradingview alert script Blue Sky Day               https://www.freelancer.com/projects/python/tra...
# UI Design + CFG Project                             https://www.freelancer.com/projects/graphic-de...
# Xbox Gamertag Claimer                               https://www.freelancer.com/projects/java/xbox-...
# clustering data streams on GPU using Matlab         https://www.freelancer.com/projects/data-proce...
# Youtube converter software                          https://www.freelancer.com/projects/mobile-pho...
# Interactive Tool for joining a series of lines ...  https://www.freelancer.com/projects/software-d...
# Scheme programming language expert                  https://www.freelancer.com/projects/software-a...
# Help me make this fun and helpful desktop assis...  https://www.freelancer.com/projects/php/help-m...
# I wanna to programmer or developer to enhanceme...  https://www.freelancer.com/projects/technical-...
# i need an expert with R5RS software                 https://www.freelancer.com/projects/software-a...
# Experienced Scala Developer                         https://www.freelancer.com/projects/scala/expe...
# Data Flow Analysis (CFG) Project                    https://www.freelancer.com/projects/database-p...
# Build a Program Poker Program for Card recognit...  https://www.freelancer.com/projects/java/build...
# Applications of Assembly Language                   https://www.freelancer.com/projects/c-programm...
# Technology(App, Website, etc) for Textile Industry  https://www.freelancer.com/projects/website-de...
# java program                                        https://www.freelancer.com/projects/software-a...
# Freshdesk + Float API intregation work/Quality ...  https://www.freelancer.com/projects/javascript...
# Photo editing online app (exporting both raster...  https://www.freelancer.com/projects/php/photo-...
# design your own t-shirt platform                    https://www.freelancer.com/projects/graphic-de...
# Build me an application in Prolog                   https://www.freelancer.com/projects/software-a...
# Build me an application                             https://www.freelancer.com/projects/programmin...
# Build me a chatbot                                  https://www.freelancer.com/projects/machine-le...
# Write something in Bios of a GPU                    https://www.freelancer.com/projects/programmin...
# API Expert Required                                 https://www.freelancer.com/projects/programmin...
# Create area and contour in Python with Bezier c...  https://www.freelancer.com/projects/python/cre...
# I have shopify store I need all prices images o...  https://www.freelancer.com/projects/website-de...
# Neurosky Mindwave EEG device visualizing EEG ou...  https://www.freelancer.com/projects/programmin...
#
# [100 rows x 2 columns]

# %% [markdown]
# # Job Matching
#
# Here, we will match a user's profile of classes and skills to the best-fit jobs listed based on a scoring system.  The function __get_matches__ takes the inputs __user_courses__ and __user_defined_skills__, both lists of courses and skills, respectively, and returns the lists of skill/course matches for all the listings.  The function __rate_matches__ will "score" each of the job listings as follows:
# 1. One point is added if a user's skill/course matches with a part of the job description.
# 2. One point is added for each unique match.

# %%
def find_text(word, text):
    return re.search(re.escape(word), text, re.IGNORECASE)

def get_matches(user_courses, user_jobs, user_defined_skills):
    jobmatches = pd.DataFrame(columns=['Matched Skills', 'Rating', 'Website'])

    for j, row in jobsdf.iterrows():
        
        temp_skills = []
        #skill is a skill needed for job J
        #for skill in j:
        for skill in jobsdf.loc[j][0]:
            # taking the courses which the user has taken.  
            for course in user_courses:
                description = course_and_description[course]
                if find_text(skill, description):
                    temp_skills.append(skill)
            #match with skills needed for the user's previous jobs
            for user_job in user_jobs:
                for jskill in jobsdf.loc[user_job]['List of Skills']:
                    if skill == jskill:
                        temp_skills.append(skill)
            # taking the skills which the user possess.
            for defined_skill in user_defined_skills:
                if skill == defined_skill:
                    temp_skills.append(skill)
        # Here we add up the points.
        rating = len(temp_skills) + len(set(temp_skills))
        if rating > 0:
            temp = pd.Series({'Matched Skills':temp_skills,'Rating':rating,'Website':jobsdf.loc[j]['Website']}) 
            jobmatches.loc[j] = temp
    jobmatches = jobmatches.sort_values(by='Rating', ascending = False)
    return jobmatches

# %%
class User:        
    def __init__(self, user_courses=[], user_jobs=[], expressed_skills=[], course_reviews=[], jobs_reviews=[]):
        # self.courses empty by default
        self.courses = user_courses
        for course in self.courses:    
            if course not in course_and_description:
                course_and_description.append(course)
        # self.user_jobs empty by default
        self.jobs = user_jobs
        # self.expressesd_skills empty by default
        self.expressed_skills = expressed_skills

        self.match_user()
        
    def match_user(self):                          
        # match jobs
        self.jobmatches = get_matches(self.courses, self.jobs, self.expressed_skills)
        
        # best match
        iterator = self.jobmatches.iterrows()
        try:
            self.best_match_name, self.best_match_series  = next(iterator)
        except StopIteration: 
            print('User has no job matches')
        
    # add_course: run this code to add more courses to the user    
    def add_course(self, course):
        if course not in course_and_description:
            course_and_description.append(course)
        self.courses += course
        self.match_user() # remember to refer back to self
        
    def review_course(self, course, feedback):
        #feedback is a STRING, skills that the user believes he learned from the course
        # check that user has taken this course
        assert course in self.courses, 'Our system has not logged that you have taken this course'
        course_and_description[course] += ' ' + feedback + ' '
        self.match_user()
    
    # express_skills: run this code to add more skills to the same user
    def add_expressed_skills(self, skills):
        self.expressed_skills += skills
        self.match_user()
    
    def add_jobs(self, job, feedback=[]):
        if job not in jobskills:
            jobskills[job] = feedback
        self.jobs += job
        self.match_user()

    def review_job(self, job, feedback):
        #feedback is in the form of a LIST, skills that the user believes he learned from the course
        # check that user has had this job
        assert job in self.jobs, 'Our system has not logged that you have had this job'
        jobskills[job].append(feedback)
        self.match_user()
        
    def __str__(self):
        return ('User: {0}, {1}, {2}, {3}, {4}'.format(self.courses, self.jobs, self.expressed_skills, self.best_match_name, self.best_match_series))

# %% [markdown]
# # Using the System

# %% [markdown]
# As mentioned before, as an example, Joe will be defining which classes he has taken and which skills he possesses. Joe's coursework has been composed into a list as defined by __user_courses__, and his skills has been composed into a list as defined by __expressed__.

# %%
# Inputting Joe's coursework and skills.
user_courses = ['CS C8. Foundations of Data Science', 'CS 160. User Interface Design and Development', 'CS 189. Introduction to Machine Learning', 'EECS 127. Optimization Models in Engineering', 'CS 9A. Matlab for Programmers', 'CS 9A-001. Self-paced courses', 'CS 9C. C for Programmers']
expressed_skills = ['Java', 'Django', 'HTML', 'Linux', 'MySQL', 'PHP', 'BeautifulSoup']
# (add something here)
Joe = User(user_courses=user_courses, expressed_skills=expressed_skills)

# %%
print("Because of your skills {0}, we have matched you with this job opportunity titled, {1}, which can be found at {2}".format(set(Joe.best_match_series['Matched Skills']), Joe.best_match_name, Joe.best_match_series['Website']))
# Out:
# Because of your skills {'C Programming', 'Graphic Design', 'Programming'}, we have matched you with this job opportunity titled, design your own t-shirt platform, which can be found at https://www.freelancer.com/projects/graphic-design/design-your-own-shirt-platform/

# %% [markdown]
# # Updating Course Data Based on User Feedback of Courses

# %% [markdown]
# A user can always access Course-To-Career in the future if he/she wishes to add more skills and coursework to his/her profile.  For example, Joe can add feedback to a certain class description if he wants stress a particular skill not mentioned in the class description. For example, consider the description of CS C8:

# %%
course_and_description['CS C8. Foundations of Data Science']
# Out:
# 'Catalog Description: Foundations of data science from three perspectives: inferential thinking, computational thinking, and real-world relevance. Given data arising from some real-world phenomenon, how does one analyze that data so as to understand that phenomenon? The course teaches critical concepts and skills in computer programming and statistical inference, in conjunction with hands-on analysis of real-world datasets, including economic data, document collections, geographical data, and social networks. It delves into social and legal issues surrounding data analysis, including issues of privacy and data ownership.<li><a href="https://eecs.berkeley.edu/academics">Academics</a></li><li><a href="https://eecs.berkeley.edu/academics/courses">Courses</a></li><li>\n<a href="https://eecs.berkeley.edu/privacy-policy"><span>Privacy Policy</span></a>\n</li>'

# %% [markdown]
# If Joe wants to add a skill learned in that course, or to stress (to put more "weight") on a particular skill when running through a job search, then he may append the course description using __review_course__. Running the following line of code will add 'data science' to the course description.

# %%
Joe.review_course('CS C8. Foundations of Data Science', 'data science')

# %% [markdown]
# Following the addition, the words "data science" are appended to the end of the description:

# %%
course_and_description['CS C8. Foundations of Data Science']
# Out:
# 'Catalog Description: Foundations of data science from three perspectives: inferential thinking, computational thinking, and real-world relevance. Given data arising from some real-world phenomenon, how does one analyze that data so as to understand that phenomenon? The course teaches critical concepts and skills in computer programming and statistical inference, in conjunction with hands-on analysis of real-world datasets, including economic data, document collections, geographical data, and social networks. It delves into social and legal issues surrounding data analysis, including issues of privacy and data ownership.<li><a href="https://eecs.berkeley.edu/academics">Academics</a></li><li><a href="https://eecs.berkeley.edu/academics/courses">Courses</a></li><li>\n<a href="https://eecs.berkeley.edu/privacy-policy"><span>Privacy Policy</span></a>\n</li> data science '

# %% [markdown]
# # What Are All Those Instance Attributes?
#
# Let me show you

# %%
print(Joe)
# Out:
# User: ['CS C8. Foundations of Data Science', 'CS 160. User Interface Design and Development', 'CS 189. Introduction to Machine Learning', 'EECS 127. Optimization Models in Engineering', 'CS 9A. Matlab for Programmers', 'CS 9A-001. Self-paced courses', 'CS 9C. C for Programmers'], [], ['Java', 'Django', 'HTML', 'Linux', 'MySQL', 'PHP', 'BeautifulSoup'], design your own t-shirt platform, Matched Skills    [C Programming, Graphic Design, Programming, P...
# Rating                                                           10
# Website           https://www.freelancer.com/projects/graphic-de...
# Name: design your own t-shirt platform, dtype: object

# %%
Joe.jobmatches
# Out:
#                                                                                        Matched Skills  \
# design your own t-shirt platform                    [C Programming, Graphic Design, Programming, P...
# I need a Java Coder                                 [Java, PHP, Programming, Programming, Programm...
# Xbox Gamertag Claimer                               [C Programming, Java, Programming, Programming...
# Build me a chatbot                                  [Machine Learning, Machine Learning, Programmi...
# Max of a row                                        [Mathematics, Mathematics, Programming, Progra...
# Help me make this fun and helpful desktop assis...  [PHP, Programming, Programming, Programming, P...
# Build Email Verification System                     [Linux, Programming, Programming, Programming,...
# API Expert Required                                 [PHP, Programming, Programming, Programming, P...
# Build Discord Bot in Python (need fast delivery)    [Java, Programming, Programming, Programming, ...
# Simple GoLang Code                                  [C Programming, Programming, Programming, Prog...
# Photo editing online app (exporting both raster...  [PHP, Programming, Programming, Programming, P...
# Experienced Scala Developer                         [Java, Programming, Programming, Programming, ...
# Person re-identification using triplet loss         [Algorithm, Machine Learning, Machine Learning...
# Scheme programming language expert                  [Algorithm, Programming, Programming, Programm...
# Youtube converter software                          [C Programming, Programming, Programming, Prog...
# Tradingview alert script Blue Sky Day               [C Programming, Programming, Programming, Prog...
# We need an experienced python/django web develo...                                [Django, HTML, PHP]
# need program for car tuner                          [Programming, Programming, Programming, Progra...
# I wanna to programmer or developer to enhanceme...  [Programming, Programming, Programming, Progra...
# Freshdesk + Float API intregation work/Quality ...  [Programming, Programming, Programming, Progra...
# Build me an application                             [Programming, Programming, Programming, Progra...
# Write something in Bios of a GPU                    [Programming, Programming, Programming, Progra...
# bluetooth pulsometer / oximeter for small animals   [Programming, Programming, Programming, Progra...
# Convert Ninja Trader Code to TradeStation (Easy...  [Programming, Programming, Programming, Progra...
# IPTV with EPG & vod reseller complete setup         [Programming, Programming, Programming, Progra...
# Django Social Media/Tinder like app fixes                                         [Django, HTML, PHP]
# Create area and contour in Python with Bezier c...  [Programming, Programming, Programming, Progra...
# Discord/Skype/ VOIP Service.                        [Programming, Programming, Programming, Progra...
# Python based ML Project Cleanup                     [Artificial Intelligence, Machine Learning, Ma...
# Data Science Trainer -- Online                      [Data Science, Machine Learning, Machine Learn...
# I need a python developer for small work                                            [PHP, Statistics]
# ODOO 8 "OpenERP" tailoring                                                               [MySQL, PHP]
# Medical Record system with any programming lang...                                        [Java, PHP]
# create a host in ubuntu to listen 5000 port                                              [Linux, PHP]
# I want to python expert.                                         [Machine Learning, Machine Learning]
# Machine Learning Assistance                                      [Machine Learning, Machine Learning]
# parsing unstructured docx files                                                               [MySQL]
# PHP Web application for embeded ARM system                                                      [PHP]
# create a extension for 2d image canvas image draw                                              [Java]
# Data Scientist expert needed                                                           [Data Science]
# I need a python developer                                                             [C Programming]
# Artificial Intelligence Assistance                                          [Artificial Intelligence]
# odoo configuration                                                                              [PHP]
# Build Simple Firewall                                                                          [Java]
#
#                                                    Rating  \
# design your own t-shirt platform                       10
# I need a Java Coder                                    10
# Xbox Gamertag Claimer                                  10
# Build me a chatbot                                      9
# Max of a row                                            9
# Help me make this fun and helpful desktop assis...      8
# Build Email Verification System                         8
# API Expert Required                                     8
# Build Discord Bot in Python (need fast delivery)        8
# Simple GoLang Code                                      8
# Photo editing online app (exporting both raster...      8
# Experienced Scala Developer                             8
# Person re-identification using triplet loss             8
# Scheme programming language expert                      8
# Youtube converter software                              8
# Tradingview alert script Blue Sky Day                   8
# We need an experienced python/django web develo...      6
# need program for car tuner                              6
# I wanna to programmer or developer to enhanceme...      6
# Freshdesk + Float API intregation work/Quality ...      6
# Build me an application                                 6
# Write something in Bios of a GPU                        6
# bluetooth pulsometer / oximeter for small animals       6
# Convert Ninja Trader Code to TradeStation (Easy...      6
# IPTV with EPG & vod reseller complete setup             6
# Django Social Media/Tinder like app fixes               6
# Create area and contour in Python with Bezier c...      6
# Discord/Skype/ VOIP Service.                            6
# Python based ML Project Cleanup                         5
# Data Science Trainer -- Online                          5
# I need a python developer for small work                4
# ODOO 8 "OpenERP" tailoring                              4
# Medical Record system with any programming lang...      4
# create a host in ubuntu to listen 5000 port             4
# I want to python expert.                                3
# Machine Learning Assistance                             3
# parsing unstructured docx files                         2
# PHP Web application for embeded ARM system              2
# create a extension for 2d image canvas image draw       2
# Data Scientist expert needed                            2
# I need a python developer                               2
# Artificial Intelligence Assistance                      2
# odoo configuration                                      2
# Build Simple Firewall                                   2
#
#                                                                                               Website
# design your own t-shirt platform                    https://www.freelancer.com/projects/graphic-de...
# I need a Java Coder                                 https://www.freelancer.com/projects/php/need-j...
# Xbox Gamertag Claimer                               https://www.freelancer.com/projects/java/xbox-...
# Build me a chatbot                                  https://www.freelancer.com/projects/machine-le...
# Max of a row                                        https://www.freelancer.com/projects/matlab-mat...
# Help me make this fun and helpful desktop assis...  https://www.freelancer.com/projects/php/help-m...
# Build Email Verification System                     https://www.freelancer.com/projects/python/bui...
# API Expert Required                                 https://www.freelancer.com/projects/programmin...
# Build Discord Bot in Python (need fast delivery)    https://www.freelancer.com/projects/java/build...
# Simple GoLang Code                                  https://www.freelancer.com/projects/data-proce...
# Photo editing online app (exporting both raster...  https://www.freelancer.com/projects/php/photo-...
# Experienced Scala Developer                         https://www.freelancer.com/projects/scala/expe...
# Person re-identification using triplet loss         https://www.freelancer.com/projects/python/per...
# Scheme programming language expert                  https://www.freelancer.com/projects/software-a...
# Youtube converter software                          https://www.freelancer.com/projects/mobile-pho...
# Tradingview alert script Blue Sky Day               https://www.freelancer.com/projects/python/tra...
# We need an experienced python/django web develo...  https://www.freelancer.com/projects/php/need-e...
# need program for car tuner                          https://www.freelancer.com/projects/programmin...
# I wanna to programmer or developer to enhanceme...  https://www.freelancer.com/projects/technical-...
# Freshdesk + Float API intregation work/Quality ...  https://www.freelancer.com/projects/javascript...
# Build me an application                             https://www.freelancer.com/projects/programmin...
# Write something in Bios of a GPU                    https://www.freelancer.com/projects/programmin...
# bluetooth pulsometer / oximeter for small animals   https://www.freelancer.com/projects/electronic...
# Convert Ninja Trader Code to TradeStation (Easy...  https://www.freelancer.com/projects/programmin...
# IPTV with EPG & vod reseller complete setup         https://www.freelancer.com/projects/android/ip...
# Django Social Media/Tinder like app fixes           https://www.freelancer.com/projects/php/django...
# Create area and contour in Python with Bezier c...  https://www.freelancer.com/projects/python/cre...
# Discord/Skype/ VOIP Service.                        https://www.freelancer.com/projects/c-sharp-pr...
# Python based ML Project Cleanup                     https://www.freelancer.com/projects/python/pyt...
# Data Science Trainer -- Online                      https://www.freelancer.com/projects/python/dat...
# I need a python developer for small work            https://www.freelancer.com/projects/php/need-p...
# ODOO 8 "OpenERP" tailoring                          https://www.freelancer.com/projects/php/odoo-o...
# Medical Record system with any programming lang...  https://www.freelancer.com/projects/php/medica...
# create a host in ubuntu to listen 5000 port         https://www.freelancer.com/projects/php/create...
# I want to python expert.                            https://www.freelancer.com/projects/software-a...
# Machine Learning Assistance                         https://www.freelancer.com/projects/python/mac...
# parsing unstructured docx files                     https://www.freelancer.com/projects/mysql/pars...
# PHP Web application for embeded ARM system          https://www.freelancer.com/projects/php/php-we...
# create a extension for 2d image canvas image draw   https://www.freelancer.com/projects/javascript...
# Data Scientist expert needed                        https://www.freelancer.com/projects/python/dat...
# I need a python developer                           https://www.freelancer.com/projects/software-a...
# Artificial Intelligence Assistance                  https://www.freelancer.com/projects/python/art...
# odoo configuration                                  https://www.freelancer.com/projects/php/odoo-c...
# Build Simple Firewall                               https://www.freelancer.com/projects/software-a...

# %%
Joe.courses
# Out:
# ['CS C8. Foundations of Data Science',
#  'CS 160. User Interface Design and Development',
#  'CS 189. Introduction to Machine Learning',
#  'EECS 127. Optimization Models in Engineering',
#  'CS 9A. Matlab for Programmers',
#  'CS 9A-001. Self-paced courses',
#  'CS 9C. C for Programmers']

# %%
Joe.jobs
# Out:
# []

# %%
Joe.expressed_skills
# Out:
# ['Java', 'Django', 'HTML', 'Linux', 'MySQL', 'PHP', 'BeautifulSoup']

# %%
Joe.best_match_name
# Out:
# 'Person re-identification using triplet loss'

# %%
Joe.best_match_series['Matched Skills']
# Out:
# ['C Programming',
#  'Graphic Design',
#  'Programming',
#  'Programming',
#  'Programming',
#  'Programming',
#  'Programming']

# %%
Joe.best_match_series['Rating']
# Out:
# 8
